# %% [markdown]
# # The Weather Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv(r'Weather Data.csv')

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
df['Wind Speed_km/h'].nunique()
# Out:
# 34

# %% [markdown]
# ### Number of Times Weather was "Clear"

# %%
df['Weather'][df['Weather'] == 'Clear'].count()
# Out:
# 1326

# %%
weather = df['Weather']

# %%
weather.count
# Out:
# <bound method Series.count of 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather, Length: 8784, dtype: object>

# %%
weather[8774:8784]
# Out:
# 8774    Snow
# 8775    Snow
# 8776    Snow
# 8777    Snow
# 8778    Snow
# 8779    Snow
# 8780    Snow
# 8781    Snow
# 8782    Snow
# 8783    Snow
# Name: Weather, dtype: object

# %%
df.groupby('Weather').get_group("Clear")
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# ### Wind = 4kmph

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df['Wind Speed_km/h'][df['Wind Speed_km/h'] == 4].count()
# Out:
# 474

# %% [markdown]
# ### Rename Weather to Weather Condition

# %%
df.rename(columns = {'Weather' : "Weather Condition", 'Wind Speed_km/h' : 'Wind Speed (km/h)'}, inplace = True)

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0        1/1/2012 0:00    -1.8              -3.9         86
# 1        1/1/2012 1:00    -1.8              -3.7         87
# 2        1/1/2012 2:00    -1.8              -3.4         89
# 3        1/1/2012 3:00    -1.5              -3.2         88
# 4        1/1/2012 4:00    -1.5              -3.3         88
# ...                ...     ...               ...        ...
# 8779  12/31/2012 19:00     0.1              -2.7         81
# 8780  12/31/2012 20:00     0.2              -2.4         83
# 8781  12/31/2012 21:00    -0.5              -1.5         93
# 8782  12/31/2012 22:00    -0.2              -1.8         89
# 8783  12/31/2012 23:00     0.0              -2.1         86
#
#       Wind Speed (km/h)  Visibility_km  Press_kPa     Weather Condition
# 0                     4            8.0     101.24                   Fog
# 1                     4            8.0     101.24                   Fog
# ...

# %%
df['Time'] = df['Date/Time'].str.split(' ').str[1]

# %%
clist = list(df.columns)

# %%
clist
# Out:
# ['Date/Time',
#  'Temp_C',
#  'Dew Point Temp_C',
#  'Rel Hum_%',
#  'Wind Speed (km/h)',
#  'Visibility_km',
#  'Press_kPa',
#  'Weather Condition',
#  'Time']

# %%
clist = clist[-1:]+clist[:-1]

# %%
df = df[clist]

# %%
df
# Out:
#        Time         Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0      0:00     1/1/2012 0:00    -1.8              -3.9         86
# 1      1:00     1/1/2012 1:00    -1.8              -3.7         87
# 2      2:00     1/1/2012 2:00    -1.8              -3.4         89
# 3      3:00     1/1/2012 3:00    -1.5              -3.2         88
# 4      4:00     1/1/2012 4:00    -1.5              -3.3         88
# ...     ...               ...     ...               ...        ...
# 8779  19:00  12/31/2012 19:00     0.1              -2.7         81
# 8780  20:00  12/31/2012 20:00     0.2              -2.4         83
# 8781  21:00  12/31/2012 21:00    -0.5              -1.5         93
# 8782  22:00  12/31/2012 22:00    -0.2              -1.8         89
# 8783  23:00  12/31/2012 23:00     0.0              -2.1         86
#
#       Wind Speed (km/h)  Visibility_km  Press_kPa     Weather Condition
# 0                     4            8.0     101.24                   Fog
# ...

# %%
df['Date'] = df['Date/Time'].str.split(' ').str[0]
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_1568\471103836.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date/Time'].str.split(' ').str[0]

# %%
clist = list(df.columns)

# %%
clist
# Out:
# ['Time',
#  'Date/Time',
#  'Temp_C',
#  'Dew Point Temp_C',
#  'Rel Hum_%',
#  'Wind Speed (km/h)',
#  'Visibility_km',
#  'Press_kPa',
#  'Weather Condition',
#  'Date']

# %%
clist = clist[-1:]+clist[:-1]
df = df[clist]

# %%
df
# Out:
#             Date   Time         Date/Time  Temp_C  Dew Point Temp_C  \
# 0       1/1/2012   0:00     1/1/2012 0:00    -1.8              -3.9
# 1       1/1/2012   1:00     1/1/2012 1:00    -1.8              -3.7
# 2       1/1/2012   2:00     1/1/2012 2:00    -1.8              -3.4
# 3       1/1/2012   3:00     1/1/2012 3:00    -1.5              -3.2
# 4       1/1/2012   4:00     1/1/2012 4:00    -1.5              -3.3
# ...          ...    ...               ...     ...               ...
# 8779  12/31/2012  19:00  12/31/2012 19:00     0.1              -2.7
# 8780  12/31/2012  20:00  12/31/2012 20:00     0.2              -2.4
# 8781  12/31/2012  21:00  12/31/2012 21:00    -0.5              -1.5
# 8782  12/31/2012  22:00  12/31/2012 22:00    -0.2              -1.8
# 8783  12/31/2012  23:00  12/31/2012 23:00     0.0              -2.1
#
#       Rel Hum_%  Wind Speed (km/h)  Visibility_km  Press_kPa  \
# 0            86                  4            8.0     101.24
# ...

# %%
df = df.drop(['Date/Time'], axis=1)

# %%
df
# Out:
#             Date   Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0       1/1/2012   0:00    -1.8              -3.9         86
# 1       1/1/2012   1:00    -1.8              -3.7         87
# 2       1/1/2012   2:00    -1.8              -3.4         89
# 3       1/1/2012   3:00    -1.5              -3.2         88
# 4       1/1/2012   4:00    -1.5              -3.3         88
# ...          ...    ...     ...               ...        ...
# 8779  12/31/2012  19:00     0.1              -2.7         81
# 8780  12/31/2012  20:00     0.2              -2.4         83
# 8781  12/31/2012  21:00    -0.5              -1.5         93
# 8782  12/31/2012  22:00    -0.2              -1.8         89
# 8783  12/31/2012  23:00     0.0              -2.1         86
#
#       Wind Speed (km/h)  Visibility_km  Press_kPa     Weather Condition
# 0                     4            8.0     101.24                   Fog
# 1                     4            8.0     101.24                   Fog
# ...
