# %% [markdown]
# # Flights EDA and Feature Engineering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_df = pd.read_excel('Datasets/Data_Train.xlsx')
test_df = pd.read_excel('Datasets/Test_set.xlsx')

# %%
train_df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
test_df.head(2)
# Out:
#        Airline Date_of_Journey   Source Destination            Route Dep_Time  \
# 0  Jet Airways       6/06/2019    Delhi      Cochin  DEL → BOM → COK    17:30
# 1       IndiGo      12/05/2019  Kolkata    Banglore  CCU → MAA → BLR    06:20
#
#    Arrival_Time Duration Total_Stops Additional_Info
# 0  04:25 07 Jun  10h 55m      1 stop         No info
# 1         10:20       4h      1 stop         No info

# %%
final_df = pd.concat([train_df, test_df])

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# # Feature Engineering - Derived Feature
# All should be in datetime format
# * Date_of_Journey  13354 non-null  object
# * Dep_Time         13354 non-null  object
# * Arrival_Time     13354 non-null  object
# * Duration         13354 non-null  object

# %% [markdown]
# ## 1. Date

# %%
final_df['Date'] = final_df['Date_of_Journey'].str.split('/').str[0]
final_df['Month'] = final_df['Date_of_Journey'].str.split('/').str[1]
final_df['Year'] = final_df['Date_of_Journey'].str.split('/').str[2]

# %% [markdown]
# #Using Lambda function:
# df['Date'] = df['Date_of_journey'].apply(lambda x:x.split("/")[0])
# df['Month'] = df['Date_of_journey'].apply(lambda x:x.split("/")[1])
# df['Year'] = df['Date_of_journey'].apply(lambda x:x.split("/")[2])

# %%
final_df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info   Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info  3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info  7662.0    1
#
#   Month  Year
# 0    03  2019
# 1    05  2019

# %%
final_df['Date'] = final_df['Date'].astype(int)
final_df['Month'] = final_df['Month'].astype(int)
final_df['Year'] = final_df['Year'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  int32
#  12  Month            13354 non-null  int32
#  13  Year             13354 non-null  int32
# dtypes: float64(1), int32(3), object(10)
# memory usage: 1.4+ MB

# %% [markdown]
# **Now You can drop Date_of_Journey**

# %%
final_df.drop('Date_of_Journey', axis=1, inplace=True)

# %%
final_df.head(10)
# Out:
#              Airline    Source Destination                  Route Dep_Time  \
# 0             IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1          Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2        Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3             IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4             IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# 5           SpiceJet   Kolkata    Banglore              CCU → BLR    09:00
# 6        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    18:55
# 7        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    08:00
# 8        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    08:55
# 9  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    11:25
#
#    Arrival_Time Duration Total_Stops              Additional_Info    Price  \
# ...

# %% [markdown]
# ## 2. Arrival_Time

# %% [markdown]
# ### **Remove date from Arrival_Time**

# %%
final_df['Arrival_Time'] = final_df['Arrival_Time'].apply(lambda x:x.split(' ')[0])

# %%
final_df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#   Arrival_Time Duration Total_Stops Additional_Info   Price  Date  Month  Year
# 0        01:10   2h 50m    non-stop         No info  3897.0    24      3  2019
# 1        13:15   7h 25m     2 stops         No info  7662.0     1      5  2019

# %% [markdown]
# ### **Now take out Hour and minute from arrival time**

# %%
final_df['Arrival_hour'] = final_df['Arrival_Time'].str.split(':').str[0]
final_df['Arrival_min'] = final_df['Arrival_Time'].str.split(':').str[1]

# %%
final_df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#   Arrival_Time Duration Total_Stops Additional_Info   Price  Date  Month  \
# 0        01:10   2h 50m    non-stop         No info  3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info  7662.0     1      5
#
#    Year Arrival_hour Arrival_min
# 0  2019           01          10
# 1  2019           13          15

# %%
final_df['Arrival_hour'] = final_df['Arrival_hour'].astype(int)
final_df['Arrival_min'] = final_df['Arrival_min'].astype(int)

# %% [markdown]
# ### Now Drop the Arrival_Time

# %%
final_df.drop('Arrival_Time',axis=1,inplace=True)

# %% [markdown]
# ## 3. Dep_Time

# %% [markdown]
# ### **Now take out Hour and minute from Dep_time**

# %%
final_df['Dep_hour'] = final_df['Dep_Time'].str.split(':').str[0]
final_df['Dep_min'] = final_df['Dep_Time'].str.split(':').str[1]

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info    Price  Date  Month  Year  Arrival_hour  \
# 0    non-stop         No info   3897.0    24      3  2019             1
# 1     2 stops         No info   7662.0     1      5  2019            13
# 2     2 stops         No info  13882.0     9      6  2019             4
# 3      1 stop         No info   6218.0    12      5  2019            23
# 4      1 stop         No info  13302.0     1      3  2019            21
#
#    Arrival_min Dep_hour Dep_min
# ...

# %%
final_df['Dep_hour'] = final_df['Dep_hour'].astype(int)
final_df['Dep_min'] = final_df['Dep_min'].astype(int)

# %%
final_df.drop('Dep_Time',axis=1,inplace=True)

# %%
final_df.head(2)
# Out:
#      Airline    Source Destination                  Route Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
#
#   Total_Stops Additional_Info   Price  Date  Month  Year  Arrival_hour  \
# 0    non-stop         No info  3897.0    24      3  2019             1
# 1     2 stops         No info  7662.0     1      5  2019            13
#
#    Arrival_min  Dep_hour  Dep_min
# 0           10        22       20
# 1           15         5       50

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  object
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Date             13354 non-null  int32
#  9   Month            13354 non-null  int32
#  10  Year             13354 non-null  int32
#  11  Arrival_hour     13354 non-null  int32
#  12  Arrival_min      13354 non-null  int32
#  13  Dep_hour         13354 non-null  int32
#  14  Dep_min          13354 non-null  int32
# dtypes: float64(1), int32(7), object(7)
# memory usage: 1.3+ MB

# %% [markdown]
# ## 4. Route

# %%
final_df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
final_df['Total_Stops'] = final_df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':1})

# %%
final_df[final_df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Duration  Total_Stops  \
# 9039  Air India  Delhi      Cochin   NaN  23h 40m          NaN
#
#      Additional_Info   Price  Date  Month  Year  Arrival_hour  Arrival_min  \
# 9039         No info  7480.0     6      5  2019             9           25
#
#       Dep_hour  Dep_min
# 9039         9       45

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info    Price  Date  Month  Year  Arrival_hour  \
# 0          0.0         No info   3897.0    24      3  2019             1
# 1          2.0         No info   7662.0     1      5  2019            13
# 2          2.0         No info  13882.0     9      6  2019             4
# 3          1.0         No info   6218.0    12      5  2019            23
# 4          1.0         No info  13302.0     1      3  2019            21
#
#    Arrival_min  Dep_hour  Dep_min
# 0           10        22       20
# 1           15         5       50
# ...

# %%
final_df.drop('Route',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_hour  Dep_min
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50

# %%
final_df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %% [markdown]
# ## 5. Duration

# %% [markdown]
# ### (A) Duration Hours

# %%
final_df['Duration_hour'] = final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
# final_df['Duration_hour'] = final_df['Duration_hour'].astype('int')

# %% [markdown]
# ### Duration of some flight is 5m so we just have to drop these records

# %%
final_df[final_df['Duration_hour']=='5m']
# Out:
#         Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 6474  Air India  Mumbai   Hyderabad       5m          2.0         No info
# 2660  Air India  Mumbai   Hyderabad       5m          2.0         No info
#
#         Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_hour  \
# 6474  17327.0     6      3  2019            16           55        16
# 2660      NaN    12      3  2019            16           55        16
#
#       Dep_min Duration_hour
# 6474       50            5m
# 2660       50            5m

# %%
final_df.drop(6474,axis=0,inplace=True)
final_df.drop(2660,axis=0,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_hour  Dep_min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50
#
#   Duration_hour
# 0             2
# 1             7
# ...

# %%
# Now into int
final_df['Duration_hour'] = final_df['Duration_hour'].astype('int')

# %%
final_df['Duration_hour']*60
# Out:
# 0        120
# 1        420
# 2       1140
# 3        300
# 4        240
#         ...
# 2666    1380
# 2667     120
# 2668     360
# 2669     900
# 2670     840
# Name: Duration_hour, Length: 13351, dtype: int32

# %% [markdown]
# ### (B) Duration Minutes

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_hour  Dep_min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50
#
#    Duration_hour
# 0              2
# 1              7
# ...

# %%
final_df['Duration_min'] = final_df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_hour  Dep_min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50
#
#    Duration_hour Duration_min
# ...

# %%
final_df['Duration_min'].unique()
# Out:
# array(['50', '25', nan, '45', '30', '5', '15', '35', '10', '20', '55',
#        '40'], dtype=object)

# %%
final_df['Duration_min'] = final_df['Duration_min'].fillna(0)

# %%
final_df
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1             Air India   Kolkata    Banglore   7h 25m          2.0
# 2           Jet Airways     Delhi      Cochin      19h          2.0
# 3                IndiGo   Kolkata    Banglore   5h 25m          1.0
# 4                IndiGo  Banglore   New Delhi   4h 45m          1.0
# ...                 ...       ...         ...      ...          ...
# 2666          Air India   Kolkata    Banglore  23h 55m          1.0
# 2667             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 2668        Jet Airways     Delhi      Cochin   6h 35m          1.0
# 2669          Air India     Delhi      Cochin  15h 15m          1.0
# 2670  Multiple carriers     Delhi      Cochin  14h 20m          1.0
#
#      Additional_Info    Price  Date  Month  Year  Arrival_hour  Arrival_min  \
# ...

# %%
final_df.drop('Duration',axis=1,inplace=True)

# %%
final_df
# Out:
#                 Airline    Source Destination  Total_Stops Additional_Info  \
# 0                IndiGo  Banglore   New Delhi          0.0         No info
# 1             Air India   Kolkata    Banglore          2.0         No info
# 2           Jet Airways     Delhi      Cochin          2.0         No info
# 3                IndiGo   Kolkata    Banglore          1.0         No info
# 4                IndiGo  Banglore   New Delhi          1.0         No info
# ...                 ...       ...         ...          ...             ...
# 2666          Air India   Kolkata    Banglore          1.0         No info
# 2667             IndiGo   Kolkata    Banglore          0.0         No info
# 2668        Jet Airways     Delhi      Cochin          1.0         No info
# 2669          Air India     Delhi      Cochin          1.0         No info
# 2670  Multiple carriers     Delhi      Cochin          1.0         No info
#
# ...

# %% [markdown]
# ## 5 Most Expensive Flights

# %%
final_df.nlargest(5, ['Price'])
# Out:
#                     Airline    Source Destination  Total_Stops  \
# 2924   Jet Airways Business  Banglore   New Delhi          1.0
# 5372   Jet Airways Business  Banglore   New Delhi          1.0
# 10364  Jet Airways Business  Banglore   New Delhi          1.0
# 1478            Jet Airways  Banglore   New Delhi          1.0
# 2618            Jet Airways  Banglore   New Delhi          1.0
#
#       Additional_Info    Price  Date  Month  Year  Arrival_hour  Arrival_min  \
# 2924   Business class  79512.0     1      3  2019            11           25
# 5372   Business class  62427.0     1      3  2019            12           25
# 10364  Business class  57209.0     1      3  2019            14           25
# 1478          No info  54826.0    18      3  2019             0           45
# 2618          No info  54826.0    18      3  2019             5            5
#
#        Dep_hour  Dep_min  Duration_hour Duration_min
# 2924          5       45              5           40
# ...

# %%
final_df_sorted= final_df.sort_values('Price',ascending=False)

# %%
final_df_sorted
# Out:
#                     Airline    Source Destination  Total_Stops  \
# 2924   Jet Airways Business  Banglore   New Delhi          1.0
# 5372   Jet Airways Business  Banglore   New Delhi          1.0
# 10364  Jet Airways Business  Banglore   New Delhi          1.0
# 5439            Jet Airways  Banglore   New Delhi          1.0
# 1478            Jet Airways  Banglore   New Delhi          1.0
# ...                     ...       ...         ...          ...
# 2666              Air India   Kolkata    Banglore          1.0
# 2667                 IndiGo   Kolkata    Banglore          0.0
# 2668            Jet Airways     Delhi      Cochin          1.0
# 2669              Air India     Delhi      Cochin          1.0
# 2670      Multiple carriers     Delhi      Cochin          1.0
#
#       Additional_Info    Price  Date  Month  Year  Arrival_hour  Arrival_min  \
# 2924   Business class  79512.0     1      3  2019            11           25
# ...

# %%
plt.bar('Airline','Price',data=final_df_sorted)
# Out:
# <BarContainer object of 13351 artists>
